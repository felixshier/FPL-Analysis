# %%
# import libraries

import requests
import pandas as pd
import numpy as np

# %%
# use FPL API to access FPL data

url = 'https://fantasy.premierleague.com/api/bootstrap-static/'
r = requests.get(url)
json = r.json()
json.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %%
# create dataframes for teams, elements, and element_type data

teams_df = pd.DataFrame(json['teams'])

elements_df = pd.DataFrame(json['elements'])

elements_types_df = pd.DataFrame(json['element_types'])

# %%
# inspect each dataframe

# %%
teams_df.head()
# Out:
#    code  draw  form  id  loss         name  played  points  position  \
# 0     3     0  None   1     0      Arsenal       0       0         0
# 1     7     0  None   2     0  Aston Villa       0       0         0
# 2    94     0  None   3     0    Brentford       0       0         0
# 3    36     0  None   4     0     Brighton       0       0         0
# 4    90     0  None   5     0      Burnley       0       0         0
#
#   short_name  ...  team_division unavailable  win  strength_overall_home  \
# 0        ARS  ...           None       False    0                   1200
# 1        AVL  ...           None       False    0                   1100
# 2        BRE  ...           None       False    0                   1010
# 3        BHA  ...           None       False    0                   1100
# 4        BUR  ...           None       False    0                   1060
#
#    strength_overall_away  strength_attack_home  strength_attack_away  \
# 0                   1250                  1130                  1150
# 1                   1160                  1120                  1140
# 2                   1020                  1020                  1030
# 3                   1130                  1150                  1190
# 4                   1070                  1040                  1090
#
#    strength_defence_home  strength_defence_away  pulse_id
# 0                   1220                   1210         1
# 1                   1080                   1100         2
# 2                   1020                   1030       130
# 3                   1100                   1130       131
# 4                   1040                   1080        43
#
# [5 rows x 21 columns]

# %%
elements_df.head()
# Out:
#    chance_of_playing_next_round chance_of_playing_this_round    code  \
# 0                           NaN                         None   80201
# 1                           NaN                         None  115918
# 2                           NaN                         None   47431
# 3                           NaN                         None   54694
# 4                           NaN                         None   58822
#
#    cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                  0                       0                  0
# 1                  0                       0                  0
# 2                  0                       0                  0
# 3                  0                       0                  0
# 4                  0                       0                  0
#
#    cost_change_start_fall  dreamteam_count  element_type ep_next  ...  \
# 0                       0                0             1     3.6  ...
# 1                       0                0             1     2.0  ...
# 2                       0                0             3     3.2  ...
# 3                       0                0             4     4.2  ...
# 4                       0                0             2     2.7  ...
#
#   threat_rank  threat_rank_type ict_index_rank ict_index_rank_type  \
# 0         333                 4            198                  13
# 1         348                15            362                  32
# 2         146                85            124                  71
# 3          32                16             50                  18
# 4         265                87            295                 101
#
#    corners_and_indirect_freekicks_order  corners_and_indirect_freekicks_text  \
# 0                                   NaN
# 1                                   NaN
# 2                                   1.0
# 3                                   NaN
# 4                                   NaN
#
#   direct_freekicks_order direct_freekicks_text  penalties_order penalties_text
# 0                    NaN                                    NaN
# 1                    NaN                                    NaN
# 2                    2.0                                    NaN
# 3                    NaN                                    1.0
# 4                    5.0                                    NaN
#
# [5 rows x 67 columns]

# %%
elements_types_df
# Out:
#    id  plural_name plural_name_short singular_name singular_name_short  \
# 0   1  Goalkeepers               GKP    Goalkeeper                 GKP
# 1   2    Defenders               DEF      Defender                 DEF
# 2   3  Midfielders               MID    Midfielder                 MID
# 3   4     Forwards               FWD       Forward                 FWD
#
#    squad_select  squad_min_play  squad_max_play  ui_shirt_specific  \
# 0             2               1               1               True
# 1             5               3               5              False
# 2             5               2               5              False
# 3             3               1               3              False
#
#   sub_positions_locked  element_count
# 0                 [12]             56
# 1                   []            180
# 2                   []            221
# 3                   []             68

# %%
# further inspect columns of elements dataframe

elements_df.columns
# Out:
# Index(['chance_of_playing_next_round', 'chance_of_playing_this_round', 'code',
#        'cost_change_event', 'cost_change_event_fall', 'cost_change_start',
#        'cost_change_start_fall', 'dreamteam_count', 'element_type', 'ep_next',
#        'ep_this', 'event_points', 'first_name', 'form', 'id', 'in_dreamteam',
#        'news', 'news_added', 'now_cost', 'photo', 'points_per_game',
#        'second_name', 'selected_by_percent', 'special', 'squad_number',
#        'status', 'team', 'team_code', 'total_points', 'transfers_in',
#        'transfers_in_event', 'transfers_out', 'transfers_out_event',
#        'value_form', 'value_season', 'web_name', 'minutes', 'goals_scored',
#        'assists', 'clean_sheets', 'goals_conceded', 'own_goals',
#        'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards',
#        'saves', 'bonus', 'bps', 'influence', 'creativity', 'threat',
#        'ict_index', 'influence_rank', 'influence_rank_type', 'creativity_rank',
#        'creativity_rank_type', 'threat_rank', 'threat_rank_type',
#        'ict_index_rank', 'ict_index_rank_type',
#        'corners_and_indirect_freekicks_order',
#        'corners_and_indirect_freekicks_text', 'direct_freekicks_order',
#        'direct_freekicks_text', 'penalties_order', 'penalties_text'],
#       dtype='object')

# %%
# filter out irrelevent columns from elements_df

slim_elements_df = elements_df[['id','first_name','second_name','team','element_type','selected_by_percent','now_cost','minutes','transfers_in','value_season','total_points', 'status']]

# map position from element_types_df into slim_elements_df

slim_elements_df['position'] = slim_elements_df.element_type.map(elements_types_df.set_index('id').singular_name)

# map team name from teams_df into slim_elements_df

slim_elements_df['team'] = slim_elements_df.team.map(teams_df.set_index('id').name)

# ensure all value info is of type int

slim_elements_df['value'] = slim_elements_df.value_season.astype(float)

# remove players with 0 minutes

slim_elements_df = slim_elements_df.loc[slim_elements_df.minutes > 0]
# Out:
# C:\Users\Felix\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Felix\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\Felix\anaconda3\envs\tf\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
# view best value players

slim_elements_df.sort_values(by = 'value', ascending = False).head(10)
# Out:
#       id first_name        second_name            team  element_type  \
# 32    30   Emiliano           Martínez     Aston Villa             1
# 240  188     Stuart             Dallas           Leeds             3
# 251  199      Illan            Meslier           Leeds             1
# 481  411      Aaron          Cresswell        West Ham             2
# 162  146    Vicente             Guaita  Crystal Palace             1
# 40    39       Matt            Targett     Aston Villa             2
# 412  353       Hugo             Lloris           Spurs             1
# 252  267       Jack           Harrison           Leeds             3
# 293  257    Ederson  Santana de Moraes        Man City             1
# 478  408     Lukasz          Fabianski        West Ham             1
#
#     selected_by_percent  now_cost  minutes  transfers_in value_season  \
# 32                 37.9        55     3420             0         33.8
# 240                16.7        55     3410             0         31.1
# 251                 4.7        50     3150             0         30.8
# 481                19.3        55     3170             0         27.8
# 162                 5.8        45     3330             0         27.6
# 40                 10.0        50     3404             0         27.6
# 412                 3.9        55     3420             0         27.1
# 252                 5.4        60     2846             0         26.7
# 293                10.5        60     3240             0         26.7
# 478                 2.4        50     3150             0         26.6
#
#      total_points status    position  value
# 32            186      a  Goalkeeper   33.8
# 240           171      a  Midfielder   31.1
# 251           154      a  Goalkeeper   30.8
# 481           153      a    Defender   27.8
# 162           124      a  Goalkeeper   27.6
# 40            138      a    Defender   27.6
# 412           149      a  Goalkeeper   27.1
# 252           160      a  Midfielder   26.7
# 293           160      a  Goalkeeper   26.7
# 478           133      a  Goalkeeper   26.6

# %%
# calculate mean value per position

pivot=slim_elements_df.pivot_table(index='position',values='value',aggfunc=np.mean).reset_index()
pivot.sort_values('value',ascending=False)
# Out:
#      position      value
# 2  Goalkeeper  14.817647
# 0    Defender  13.777165
# 3  Midfielder  11.826994
# 1     Forward  11.214894

# %%
# calculate mean value per team

team_pivot = slim_elements_df.pivot_table(index='team',values='value',aggfunc=np.mean).reset_index()
team_pivot.sort_values('value',ascending=False)
# Out:
#               team      value
# 10        Man City  15.261905
# 7            Leeds  15.021053
# 17        West Ham  14.945000
# 1      Aston Villa  14.115000
# 8        Leicester  13.842857
# 4          Chelsea  13.780000
# 0          Arsenal  13.382609
# 2         Brighton  13.160000
# 11         Man Utd  12.673913
# 5   Crystal Palace  12.357895
# 15           Spurs  12.100000
# 6          Everton  12.029167
# 3          Burnley  12.023810
# 18          Wolves  12.013636
# 14     Southampton  11.220000
# 12       Newcastle  10.634783
# 9        Liverpool   9.396154
# 16         Watford   2.000000
# 13         Norwich   1.800000

# %%
# create new dataframes for each position

fwd_df = slim_elements_df.loc[slim_elements_df.position == 'Forward']
mid_df = slim_elements_df.loc[slim_elements_df.position == 'Midfielder']
def_df = slim_elements_df.loc[slim_elements_df.position == 'Defender']
goal_df = slim_elements_df.loc[slim_elements_df.position == 'Goalkeeper']

# %%
# histogram of goalkeeper values

goal_df.value.hist()
# Out:
# <AxesSubplot:>

# %%
# most valuable goalkeepers

goal_df.sort_values('value',ascending=False).head(10)
# Out:
#       id first_name          second_name            team  element_type  \
# 32    30   Emiliano             Martínez     Aston Villa             1
# 251  199      Illan              Meslier           Leeds             1
# 162  146    Vicente               Guaita  Crystal Palace             1
# 412  353       Hugo               Lloris           Spurs             1
# 293  257    Ederson    Santana de Moraes        Man City             1
# 478  408     Lukasz            Fabianski        West Ham             1
# 500  427  Rui Pedro  dos Santos Patrício          Wolves             1
# 0      1      Bernd                 Leno         Arsenal             1
# 126  112       Nick                 Pope         Burnley             1
# 209  200     Kasper           Schmeichel       Leicester             1
#
#     selected_by_percent  now_cost  minutes  transfers_in value_season  \
# 32                 37.9        55     3420             0         33.8
# 251                 4.7        50     3150             0         30.8
# 162                 5.8        45     3330             0         27.6
# 412                 3.9        55     3420             0         27.1
# 293                10.5        60     3240             0         26.7
# 478                 2.4        50     3150             0         26.6
# 500                 0.1        50     3330             0         26.4
# 0                   2.3        50     3131             0         26.2
# 126                 4.9        55     2880             0         26.2
# 209                16.2        50     3420             0         25.6
#
#      total_points status    position  value
# 32            186      a  Goalkeeper   33.8
# 251           154      a  Goalkeeper   30.8
# 162           124      a  Goalkeeper   27.6
# 412           149      a  Goalkeeper   27.1
# 293           160      a  Goalkeeper   26.7
# 478           133      a  Goalkeeper   26.6
# 500           132      u  Goalkeeper   26.4
# 0             131      a  Goalkeeper   26.2
# 126           144      a  Goalkeeper   26.2
# 209           128      a  Goalkeeper   25.6

# %%
# histogram of defenders

def_df.value.hist()
# Out:
# <AxesSubplot:>

# %%
# most valuable defenders

def_df.sort_values('value',ascending=False).head(10)
# Out:
#       id    first_name      second_name         team  element_type  \
# 481  411         Aaron        Cresswell     West Ham             2
# 40    39          Matt          Targett  Aston Villa             2
# 325  288         Aaron      Wan-Bissaka      Man Utd             2
# 92    59         Lewis             Dunk     Brighton             2
# 488  418      Vladimir           Coufal     West Ham             2
# 39    38        Tyrone            Mings  Aston Villa             2
# 190  169       Michael            Keane      Everton             2
# 46    45          Ezri      Konsa Ngoyo  Aston Villa             2
# 298  262  Rúben Santos  Gato Alves Dias     Man City             2
# 502  429         Conor            Coady       Wolves             2
#
#     selected_by_percent  now_cost  minutes  transfers_in value_season  \
# 481                19.3        55     3170             0         27.8
# 40                 10.0        50     3404             0         27.6
# 325                11.0        55     3060             0         26.2
# 92                  6.9        50     2932             0         26.0
# 488                15.0        50     3054             0         25.6
# 39                  8.6        50     3194             0         25.6
# 190                 3.0        50     2989             0         25.4
# 46                  1.2        50     3195             0         23.8
# 298                27.4        60     2843             0         23.7
# 502                 8.0        45     3303             0         23.6
#
#      total_points status  position  value
# 481           153      a  Defender   27.8
# 40            138      a  Defender   27.6
# 325           144      a  Defender   26.2
# 92            130      a  Defender   26.0
# 488           128      a  Defender   25.6
# 39            128      a  Defender   25.6
# 190           127      a  Defender   25.4
# 46            119      a  Defender   23.8
# 298           142      a  Defender   23.7
# 502           106      a  Defender   23.6

# %%
# histogram of midfielders

mid_df.value.hist()
# Out:
# <AxesSubplot:>

# %%
# most valuable midfielders

mid_df.sort_values('value',ascending=False).head(10)
# Out:
#       id    first_name  second_name         team  element_type  \
# 240  188        Stuart       Dallas        Leeds             3
# 252  267          Jack     Harrison        Leeds             3
# 492  422         Tomas       Soucek     West Ham             3
# 394  341         James  Ward-Prowse  Southampton             3
# 418  359     Heung-Min          Son        Spurs             3
# 34    32      Bertrand       Traoré  Aston Villa             3
# 490  420        Jarrod        Bowen     West Ham             3
# 424  365  Pierre-Emile     Højbjerg        Spurs             3
# 286  250         Ilkay     Gündogan     Man City             3
# 493  423         Pablo      Fornals     West Ham             3
#
#     selected_by_percent  now_cost  minutes  transfers_in value_season  \
# 240                16.7        55     3410             0         31.1
# 252                 5.4        60     2846             0         26.7
# 492                11.8        60     3420             0         24.5
# 394                 3.1        65     3420             0         24.0
# 418                21.6       100     3119             0         22.8
# 34                  2.1        60     2315             0         22.5
# 490                 2.0        65     2556             0         21.7
# 424                 3.0        50     3420             0         21.4
# 286                 7.5        75     2025             0         20.9
# 493                 0.5        60     2571             0         20.8
#
#      total_points status    position  value
# 240           171      a  Midfielder   31.1
# 252           160      a  Midfielder   26.7
# 492           147      a  Midfielder   24.5
# 394           156      d  Midfielder   24.0
# 418           228      a  Midfielder   22.8
# 34            135      a  Midfielder   22.5
# 490           141      a  Midfielder   21.7
# 424           107      a  Midfielder   21.4
# 286           157      a  Midfielder   20.9
# 493           125      a  Midfielder   20.8

# %%
# histogram of forwards

fwd_df.value.hist()
# Out:
# <AxesSubplot:>

# %%
# most valuable forwards

fwd_df.sort_values('value',ascending=False).head(10)
# Out:
#       id   first_name    second_name         team  element_type  \
# 241  189      Patrick        Bamford        Leeds             4
# 41    40        Ollie        Watkins  Aston Villa             4
# 198  177      Dominic  Calvert-Lewin      Everton             4
# 123  109        Chris           Wood      Burnley             4
# 398  345          Che          Adams  Southampton             4
# 416  357        Harry           Kane        Spurs             4
# 339  296       Callum         Wilson    Newcastle             4
# 214  205        Jamie          Vardy    Leicester             4
# 55   337        Danny           Ings  Aston Villa             4
# 201  180  Richarlison     de Andrade      Everton             4
#
#     selected_by_percent  now_cost  minutes  transfers_in value_season  \
# 241                20.2        80     3052             0         24.2
# 41                 11.3        75     3328             0         22.4
# 198                12.2        80     2871             0         20.6
# 123                 3.3        70     2741             0         19.7
# 398                 2.0        70     2662             0         19.6
# 416                21.5       125     3083             0         19.4
# 339                 7.1        75     2081             0         17.9
# 214                12.8       105     2838             0         17.8
# 55                 29.8        80     2172             0         16.4
# 201                 8.5        75     2862             0         16.4
#
#      total_points status position  value
# 241           194      a  Forward   24.2
# 41            168      d  Forward   22.4
# 198           165      d  Forward   20.6
# 123           138      a  Forward   19.7
# 398           137      a  Forward   19.6
# 416           242      a  Forward   19.4
# 339           134      a  Forward   17.9
# 214           187      a  Forward   17.8
# 55            131      a  Forward   16.4
# 201           123      a  Forward   16.4

# %%
slim_elements_df['team'].unique()
# Out:
# array(['Arsenal', 'Aston Villa', 'Brighton', 'Burnley', 'Chelsea',
#        'Crystal Palace', 'Everton', 'Leicester', 'Leeds', 'Liverpool',
#        'Man City', 'Man Utd', 'Newcastle', 'Norwich', 'Southampton',
#        'Spurs', 'Watford', 'West Ham', 'Wolves'], dtype=object)

# %%
def get_money_team(data = slim_elements_df, budget = 1000, num_goal = 2, num_def = 5, num_mid = 5, num_fwd = 3):
    money_team = []
    budget = budget
    positions = {'Goalkeeper':num_goal, 'Defender':num_def, 'Midfielder':num_mid, 'Forward':num_fwd}
    teams = {'Arsenal':3, 'Aston Villa':3, 'Brighton':3, 'Burnley':3, 'Chelsea':3, 
             'Crystal Palace':3, 'Everton':3, 'Leicester':3, 'Leeds':3, 'Liverpool':3, 
             'Man City':3, 'Man Utd':3, 'Newcastle':3, 'Norwich':3, 'Southampton':3, 
             'Spurs':3, 'Watford':3, 'West Ham':3, 'Wolves':3, 'Brentford':3, }
    for idx, player in slim_elements_df.sort_values(by = 'value', ascending = False).iterrows():
        if len(money_team) <= 15 and budget >= player.now_cost and positions[player.position] > 0 and teams[player.team] > 0 and player.status == 'a':
            
            money_team.append(player)
            budget -= player.now_cost
            positions[player.position] -= 1
            teams[player.team] -= 1
        else:
            continue
    return money_team

# %%
money_team = get_money_team(slim_elements_df)
money_team = pd.DataFrame(money_team)

# %%
money_team
# Out:
#       id first_name  second_name         team  element_type  \
# 32    30   Emiliano     Martínez  Aston Villa             1
# 240  188     Stuart       Dallas        Leeds             3
# 251  199      Illan      Meslier        Leeds             1
# 481  411      Aaron    Cresswell     West Ham             2
# 40    39       Matt      Targett  Aston Villa             2
# 252  267       Jack     Harrison        Leeds             3
# 325  288      Aaron  Wan-Bissaka      Man Utd             2
# 92    59      Lewis         Dunk     Brighton             2
# 488  418   Vladimir       Coufal     West Ham             2
# 492  422      Tomas       Soucek     West Ham             3
# 418  359  Heung-Min          Son        Spurs             3
# 34    32   Bertrand       Traoré  Aston Villa             3
# 123  109      Chris         Wood      Burnley             4
# 398  345        Che        Adams  Southampton             4
# 416  357      Harry         Kane        Spurs             4
#
#     selected_by_percent  now_cost  minutes  transfers_in value_season  \
# 32                 37.9        55     3420             0         33.8
# 240                16.7        55     3410             0         31.1
# 251                 4.7        50     3150             0         30.8
# 481                19.3        55     3170             0         27.8
# 40                 10.0        50     3404             0         27.6
# 252                 5.4        60     2846             0         26.7
# 325                11.0        55     3060             0         26.2
# 92                  6.9        50     2932             0         26.0
# 488                15.0        50     3054             0         25.6
# 492                11.8        60     3420             0         24.5
# 418                21.6       100     3119             0         22.8
# 34                  2.1        60     2315             0         22.5
# 123                 3.3        70     2741             0         19.7
# 398                 2.0        70     2662             0         19.6
# 416                21.5       125     3083             0         19.4
#
#      total_points status    position  value
# 32            186      a  Goalkeeper   33.8
# 240           171      a  Midfielder   31.1
# 251           154      a  Goalkeeper   30.8
# 481           153      a    Defender   27.8
# 40            138      a    Defender   27.6
# 252           160      a  Midfielder   26.7
# 325           144      a    Defender   26.2
# 92            130      a    Defender   26.0
# 488           128      a    Defender   25.6
# 492           147      a  Midfielder   24.5
# 418           228      a  Midfielder   22.8
# 34            135      a  Midfielder   22.5
# 123           138      a     Forward   19.7
# 398           137      a     Forward   19.6
# 416           242      a     Forward   19.4

# %%
sum(money_team['now_cost'])
# Out:
# 965
